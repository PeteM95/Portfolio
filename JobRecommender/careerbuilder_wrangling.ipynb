# %%
import sqlite3

import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import unicodedata
import re
from fireworks.client import Fireworks
import logging

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
fireworks_api_key = 'fw_3ZZL7o5gW7uXcibaK3woWnP6'
client = Fireworks(api_key=fireworks_api_key)

# %%
con = sqlite3.connect('careerbuilder.db')
cursor = con.cursor()

# %%
def clean_job_description(description: str) -> str:
    '''
    Clean the job descriptions up by removing all HTML elements and unwanted characters.
    :param description: raw description string
    :return: cleaned job description string
    '''
    if not isinstance(description, str) or description is None:
        return description

    try:
        soup = BeautifulSoup(description, 'html.parser')
        cleaned_desc = soup.get_text().strip()  # Extract text and remove leading/trailing spaces

        # Normalize Unicode text
        cleaned_desc = unicodedata.normalize('NFKC', cleaned_desc)

        # Replace problematic fraction symbols
        cleaned_desc = cleaned_desc.replace("â", "/")  # Fix 1⁄2 fraction separator
        cleaned_desc = cleaned_desc.replace("1⁄2", "1/2")  # Replace any remaining fraction symbols

        # Remove bullet points (• and other similar symbols)
        cleaned_desc = re.sub(r"[•●▪▶◾■◆◇]", "", cleaned_desc)

        # Encode and Decode to remove escaped characters
        cleaned_desc = cleaned_desc.encode().decode('unicode-escape')

        # Replace unwanted characters
        cleaned_desc = cleaned_desc.replace("\r", "").replace("\n", " ")  # Removes \r and \n

        # Remove extra spaces
        cleaned_desc = re.sub(r"\s+", " ", cleaned_desc).strip()

        return cleaned_desc
    except Exception as e:
        logging.error(f'Error while cleaning description: {e} \n returning original string')
        # Normalize unicode text
        cleaned_desc = unicodedata.normalize('NFKC', description)

        # Remove bullet points (• and other similar symbols)
        cleaned_desc = re.sub(r"[•●▪▶◾■◆◇]", "", cleaned_desc)

        # encode and decode to remove escaped characters
        cleaned_desc = cleaned_desc.encode().decode('unicode-escape')

        # Replace newline characters with spaces.
        cleaned_desc = cleaned_desc.replace("\n", " ")
        cleaned_desc = cleaned_desc.replace("\r", "")
        return cleaned_desc

# %%
user_1 = pd.read_sql('select * from users LIMIT 1', con = con)
user_1
# Out:
#    user_id  window_id  split       city state country zipcode  degree_type  \
# 0       47          1  Train  Paramount    CA      US   90723  High School
#
#   major      graduation_date  work_history_count  total_years_experience  \
# 0  None  1999-06-01 00:00:00                   3                    10.0
#
#   currently_employed managed_others  managed_how_many  \
# 0                Yes             No                 0
#
#                                     generated_resume
# 0  SUMMARY:\nThe client is a highly motivated ind...

# %%
user_1_apps = pd.read_sql(f'SELECT * FROM apps WHERE user_id = {user_1["user_id"].item()}', con = con)
user_1_apps
# Out:
#    app_id  user_id  window_id  split         application_date  job_id
# 0       0       47          1  Train  2012-04-04 15:56:23.537  169528
# 1       1       47          1  Train  2012-04-06 01:03:00.003  284009
# 2       2       47          1  Train  2012-04-05 02:40:27.753    2121
# 3       3       47          1  Train  2012-04-05 02:37:02.673  848187
# 4       4       47          1  Train  2012-04-05 22:44:06.653  733748
# 5       5       47          1  Train  2012-04-05 02:34:40.223  576958
# 6       6       47          1  Train  2012-04-05 22:55:03.583  262470
# 7       7       47          1  Train   2012-04-05 02:38:49.52  602298

# %%
job_ids = [str(id) for id in user_1_apps["job_id"].to_list()]
query = f"SELECT * FROM jobs WHERE job_id IN ({', '.join(job_ids)})"
applied_jobs = pd.read_sql_query(query, con = con)

# %%
applied_jobs
# Out:
#    job_id  window_id                                            title  \
# 0    2121          1                            MEDICAL- FRONT OFFICE
# 1  169528          1  Resort Host/Marketing Coordinator - Anaheim, CA
# 2  262470          1                Account Manager- Customer Service
# 3  284009          1                         Administrative Assistant
# 4  576958          1                                     RECEPTIONIST
# 5  602298          1                            Customer Service Rep.
# 6  733748          1                         Administrative Assistant
# 7  848187          1                         Administrative Assistant
#
#                                          description  \
# 0  Medical -  Front Office\r\nIndustrial Clinic, ...
# 1  <P STYLE="MARGIN-TOP: 0px; MARGIN-BOTTOM: 0px"...
# 2  Staffmark has partnered with an aerospace manu...
# 3  <p><strong>Administrative Assistant $60K - $65...
# 4  WE NEED A SPIRITED, OUT GOING PERSON TO JOIN O...
# 5  Customer Service Customer Service Rep. SANTA M...
# 6  One of the largest oilfield services companies...
# 7  <DIV>\r<P><SPAN>ADMINISTRATIVE ASSISTANT</SPAN...
#
#                                         requirements              city state  \
# 0  Please refer to the Job Description to view th...       Los Angeles    CA
# 1  • Bachelor's Degree preferred;<BR> \r\n• Posse...           Anaheim    CA
# 2  <strong><span style="text-decoration: underlin...        Buena Park    CA
# 3  Requirement:&nbsp; 2-4 years of significant ex...       Los Angeles    CA
# 4  GREET ALL PATIENTS WITH A SMILE AND BY NAME  <...       San Gabriel    CA
# 5  Please refer to the Job Description to view th...  Rancho Dominguez    CA
# 6                                               None        Long Beach    CA
# 7  <P><SPAN style="TEXT-DECORATION: underline"></...       Los Angeles    CA
#
#   country   zip5               start_date             end_date
# 0      US  90066  2012-03-09 18:07:59.063  2012-04-08 23:59:59
# 1      US  92801   2012-04-03 22:31:26.41  2012-05-02 23:59:59
# 2      US  90620   2012-04-04 17:07:51.35  2012-05-03 23:59:59
# 3      US  90036  2012-03-26 00:22:39.093  2012-04-25 23:59:59
# 4      US  91775  2012-03-11 11:43:48.003  2012-04-10 23:59:59
# 5      US  90220  2012-03-23 16:10:51.293  2012-04-22 23:59:59
# 6      US   None   2012-03-07 06:43:12.37  2012-04-06 23:59:59
# 7      US  90071   2012-03-19 17:55:56.67  2012-04-18 23:59:59

# %%
applied_jobs['cleaned_description'] = applied_jobs.apply(lambda x: clean_job_description(x['description']), axis=1)
applied_jobs['cleaned_requirements'] = applied_jobs.apply(lambda x: clean_job_description(x['requirements']), axis=1)
applied_jobs = applied_jobs.replace(r'^\s*$', None, regex=True)
applied_jobs
# Out:
#    job_id  window_id                                            title  \
# 0    2121          1                            MEDICAL- FRONT OFFICE
# 1  169528          1  Resort Host/Marketing Coordinator - Anaheim, CA
# 2  262470          1                Account Manager- Customer Service
# 3  284009          1                         Administrative Assistant
# 4  576958          1                                     RECEPTIONIST
# 5  602298          1                            Customer Service Rep.
# 6  733748          1                         Administrative Assistant
# 7  848187          1                         Administrative Assistant
#
#                                          description  \
# 0  Medical -  Front Office\r\nIndustrial Clinic, ...
# 1  <P STYLE="MARGIN-TOP: 0px; MARGIN-BOTTOM: 0px"...
# 2  Staffmark has partnered with an aerospace manu...
# 3  <p><strong>Administrative Assistant $60K - $65...
# 4  WE NEED A SPIRITED, OUT GOING PERSON TO JOIN O...
# 5  Customer Service Customer Service Rep. SANTA M...
# 6  One of the largest oilfield services companies...
# 7  <DIV>\r<P><SPAN>ADMINISTRATIVE ASSISTANT</SPAN...
#
#                                         requirements              city state  \
# 0  Please refer to the Job Description to view th...       Los Angeles    CA
# 1  • Bachelor's Degree preferred;<BR> \r\n• Posse...           Anaheim    CA
# 2  <strong><span style="text-decoration: underlin...        Buena Park    CA
# 3  Requirement:&nbsp; 2-4 years of significant ex...       Los Angeles    CA
# 4  GREET ALL PATIENTS WITH A SMILE AND BY NAME  <...       San Gabriel    CA
# 5  Please refer to the Job Description to view th...  Rancho Dominguez    CA
# 6                                               None        Long Beach    CA
# 7  <P><SPAN style="TEXT-DECORATION: underline"></...       Los Angeles    CA
#
#   country   zip5               start_date             end_date  \
# 0      US  90066  2012-03-09 18:07:59.063  2012-04-08 23:59:59
# 1      US  92801   2012-04-03 22:31:26.41  2012-05-02 23:59:59
# 2      US  90620   2012-04-04 17:07:51.35  2012-05-03 23:59:59
# 3      US  90036  2012-03-26 00:22:39.093  2012-04-25 23:59:59
# 4      US  91775  2012-03-11 11:43:48.003  2012-04-10 23:59:59
# 5      US  90220  2012-03-23 16:10:51.293  2012-04-22 23:59:59
# 6      US   None   2012-03-07 06:43:12.37  2012-04-06 23:59:59
# 7      US  90071   2012-03-19 17:55:56.67  2012-04-18 23:59:59
#
#                                  cleaned_description  \
# 0  Medical - Front Office Industrial Clinic, Full...
# 1  Wyndham Vacation Ownership is the world's larg...
# 2  Staffmark has partnered with an aerospace manu...
# 3  Administrative Assistant $60K - $65KOur client...
# 4  WE NEED A SPIRITED, OUT GOING PERSON TO JOIN O...
# 5  Customer Service Customer Service Rep. SANTA M...
# 6  One of the largest oilfield services companies...
# 7  ADMINISTRATIVE ASSISTANT A&E Support Services,...
#
#                                 cleaned_requirements
# 0  Please refer to the Job Description to view th...
# 1  Bachelor's Degree preferred; Possess excellent...
# 2  Experience with distribution or manufacturing ...
# 3  Requirement: 2-4 years of significant experien...
# 4  GREET ALL PATIENTS WITH A SMILE AND BY NAME SC...
# 5  Please refer to the Job Description to view th...
# 6                                               None
# 7                                               None

# %%
def build_LLM_query(query_dicts: dict) -> str:
    '''
    Build the query for the LLM using the instruction prompt and all the details from the user and their interactions.
    :param query_dicts: Dict where each key is a user_id and each value is a Dict of query components.
    :return: Dict[str] where the keys are the user_id's and the items are query strings
    '''

    if not isinstance(query_dicts, dict):
        raise TypeError("query_dicts is not a dictionary!")

    for key, value in query_dicts.items():
        if not isinstance(value, dict):
            raise TypeError(f"query_dicts[{key}] is not a dictionary but {type(value)}")

    final_queries = {}
    for key, item in query_dicts.items():
        query_components = [
            "You are a career advisor tasked with writing a resume for a client given their categorical descriptors, their job history, and the types of jobs they have applied at recently (and therefore find desirable).\nThe client’s description begins and ends with [CLIENT] [/CLIENT] tokens, respectively.\n\n[CLIENT]\nCategorical Descriptors:"
        ]

        # Add categorical descriptors from user table
        if item['degree_type'] is not None:
            query_components.append(f'Highest Education: {item["degree_type"]}')
        if item['major'] is not None:
            query_components.append(f'Education Major: {item["major"]}')
        if item['graduation_date'] is not None:
            query_components.append(f'Graduation Date: {item["graduation_date"]}')
        if item['total_years_experience'] is not None:
            query_components.append(f'Total Years of Experience: {item["total_years_experience"]}')
        if item['currently_employed'] is not None:
            query_components.append(f'Currently Employed: {item["currently_employed"]}')
        if item['managed_others'] is not None:
            query_components.append(f'Has Experience Managing Others: {item["managed_others"]}')
        if item['managed_how_many'] is not None:
            query_components.append(f'Number of People Managed: {item["managed_how_many"]}')

        # Add job titles from user_history table
        query_components.append('Job History (from most recent to furthest ago):')

        if item['job_history'] is not None:
            sorted_jobs = sorted(item['job_history'], key = lambda x: int(x['sequence']))
            for job in sorted_jobs:
                if job['job_title'] is not None:
                    query_components.append(job["job_title"])
        else:
            query_components.append('No job history.')

        # Add job descriptions of jobs the user has applied to
        query_components.append('Job descriptions of jobs the user has recently applied to (most recent to furthest ago):')

        if item['job_applications'] is not None:
            for job in item['job_applications']:
                if job['title'] is not None:
                    query_components.append(f'Title: {job["title"]}')
                if job['description'] is not None:
                    query_components.append(f'Description: {job["description"]}')
                if job['requirements'] is not None:
                    query_components.append(f'Requirements: {job["requirements"]}')
        else:
            query_components.append('No job applications.')

        query_components.append("[/CLIENT]\n")
        query_components.append("Answer the following Questions:\n1. What are some likely tasks the client accomplished in their previous job roles? Use their titles to infer tasks.\n2. What skills does the user likely have from their previous job roles and education?\n3. Tailor the client’s skills to the jobs they are applying at. Assume the client has some skills similar to those required at the jobs they are applying to.\n4. What is a good summary of the client’s previous job roles, skills, and jobs they are applying to?\n")
        query_components.append("Fill in the following resume template with the answers to those questions:\n\n[BEGIN]\nSUMMARY:\n(Summary of the user, their desires, and their skills)\n\nWORK EXPERIENCE:\n(List job title and tasks they likely accomplished at the jobs)\n\nEDUCATION:\n(List their education)\n\nSKILLS:\n(Infer skills from their work experience, education, and managerial responsibilities)\n[END]\n\nOnly reply with that format, no boilerplate language. Limit the output to 400 tokens.")

        full_query = '\n'.join(query_components)
        final_queries[key] = full_query

    return final_queries

# %%
def orchestrate_LLM_query_build_batch(user_ids: list):
    try:
        # Convert list to a comma-separated string for SQL
        user_ids_str = ', '.join(map(str, user_ids))

        # Fetch all users at once
        user_records = pd.read_sql_query(f'SELECT * FROM users WHERE user_id IN ({user_ids_str})', con=con)

        # Fetch all applications at once
        applications_records = pd.read_sql_query(f'SELECT * FROM apps WHERE user_id IN ({user_ids_str})', con=con)

        # Fetch all job history at once
        user_history = pd.read_sql_query(f'SELECT * FROM user_history WHERE user_id IN ({user_ids_str})', con=con)

        # Fetch all job postings applied to (batch query instead of one per user)
        applied_jobs_query = f"WITH cte AS (SELECT apps.user_id AS user_id, apps.split AS split, DATETIME(apps.application_date) AS application_date, apps.job_id AS job_id, jobs.title AS title, jobs.description AS description, jobs.requirements AS requirements, ROW_NUMBER() OVER(PARTITION BY user_id ORDER BY application_date DESC) AS date_rank FROM apps INNER JOIN jobs ON apps.job_id = jobs.job_id WHERE apps.user_id IN ({user_ids_str})) SELECT * FROM cte WHERE date_rank <= 10;"
        applied_jobs = pd.read_sql_query(applied_jobs_query, con=con)

        # Clean descriptions in bulk
        applied_jobs['cleaned_description'] = applied_jobs['description'].apply(clean_job_description)
        applied_jobs['cleaned_requirements'] = applied_jobs['requirements'].apply(clean_job_description)

        # Replace empty strings with None
        applied_jobs = applied_jobs.replace(r'^\s*$', None, regex=True)

        # Build query dictionaries for all users
        query_dicts = {}
        for user_id in user_ids:
            user_data = user_records[user_records['user_id'] == user_id]
            user_apps = applications_records[applications_records['user_id'] == user_id]
            user_hist = user_history[user_history['user_id'] == user_id]
            user_jobs = applied_jobs[applied_jobs['job_id'].isin(user_apps['job_id'])]

            query_dicts[user_id] = {
                'degree_type': user_data['degree_type'].iloc[0],
                'major': user_data['major'].iloc[0],
                'graduation_date': pd.to_datetime(user_data['graduation_date']).dt.strftime('%b %-d, %Y').iloc[0],
                'total_years_experience': str(user_data['total_years_experience'].iloc[0]),
                'currently_employed': user_data['currently_employed'].iloc[0],
                'managed_others': user_data['managed_others'].iloc[0],
                'managed_how_many': str(user_data['managed_how_many'].iloc[0]),
                'job_history': user_hist[['sequence', 'job_title']].astype(str).to_dict(orient='records'),
                'job_applications': user_jobs[['title', 'cleaned_description', 'cleaned_requirements']]
                .rename(columns={'cleaned_description': 'description', 'cleaned_requirements': 'requirements'})
                .to_dict(orient='records')
            }

        return query_dicts

    except Exception as e:
        logging.error(f'Error in orchestrating LLM query: {e}')

# %%
def fireworks_api_call(query: str, user_id: int, model_name: str = 'accounts/fireworks/models/llama-v3p3-70b-instruct'):
    """
    Make calls to Fireworks API and prompt the LLM for a response. The paramaters are tunable and the current set is based on experimentation.
    :param query: Query string to pass to the LLM.
    :param user_id: User ID taken for logging purposes.
    :param model_name: model path to use.
    :return: A string containing the LLM-generated resume.
    """
    try:
        response = client.completion.create(
            model=model_name,
            stream=False,
            prompt=query,
            max_tokens=627,
            temperature=round(np.random.uniform(1.3, 1.8), 1),
            top_p=1,
            top_k=40,
            presence_penalty=0,
            frequency_penalty=0,
            echo=False
        )
        return response.choices[0].text

    except Exception as e:
        logging.error(f'Error in Fireworks API call for user {user_id}: {e}')

# %% [markdown]
# The following section runs the loop to query the LLM API for resumes and store them in the SQLite database. The queries are batched for efficiency and robustness.

# %%
# Create sample of unique users so I'm not running 350k queries through the API
# Also, filter users list so that I'm not taking users with abnormal amounts of applications (right-tailed distribution)
# Added a filter to restrict to window 1
users_for_gen_query = "WITH cte AS (SELECT user_id, COUNT(DISTINCT(job_id)) AS n_apps FROM apps GROUP BY user_id HAVING n_apps <= 100) SELECT u.user_id, u.split, c.n_apps FROM users u INNER JOIN cte c ON u.user_id = C.user_id WHERE u.split = 'Train' AND u.window_id = 1;"
unique_users = pd.read_sql_query(users_for_gen_query, con = con)
sample_of_unique_users = unique_users.sample(n=2000).reset_index(drop=True)['user_id'].to_list()

# %%
batch_size = 50

for i in range(0, len(sample_of_unique_users), batch_size):
    response_list = []

    # Pull the next batch of user_ids
    batch = sample_of_unique_users[i:i + batch_size]

    # Fetch data for the batch
    query_dicts = orchestrate_LLM_query_build_batch(batch)
    queries = build_LLM_query(query_dicts)

    # Generate resumes for the batch
    for user_id, query in queries.items():     # This should probably be passing in the entire dict[dict], not just dict.
        try:
            response = fireworks_api_call(query=query, user_id=user_id)
            update_text = response.split('[BEGIN]')[1].split('[END]')[0].strip()
            response_list.append((update_text, user_id))
        except Exception as e:
            logging.error(f'Error in Fireworks API call for user {user_id}: {e}')
            continue

    # Update SQLite database in batches
    cursor.executemany('UPDATE users SET generated_resume=? WHERE user_id=?', response_list)
    con.commit()

    logging.info(f'Successfully generated and stores resumes for batch {(i // batch_size)+1}/{(len(sample_of_unique_users)//batch_size)}.')
# Out:
# 2025-02-27 11:14:52,822 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:14:58,454 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:15:06,238 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:15:16,476 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:15:21,085 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:15:26,001 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:15:29,994 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:15:33,372 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:15:36,753 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:15:55,914 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:15:59,894 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:16:11,773 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:16:16,074 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:16:23,140 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:16:29,034 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:16:32,971 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:16:39,115 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:16:42,188 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:16:45,569 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:16:49,559 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:16:52,938 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:16:56,634 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:17:00,371 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:17:06,762 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:17:27,037 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:17:31,645 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:17:39,018 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:17:46,085 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:17:52,433 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:17:57,448 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:03,286 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:07,690 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:14,962 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:20,795 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:25,099 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:30,320 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:34,425 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:38,922 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:41,585 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:45,066 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:49,981 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:18:53,361 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:00,426 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:04,730 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:11,895 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:18,855 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:24,317 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:29,915 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:34,014 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:38,211 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:38,228 - INFO - Successfully generated and stores resumes for batch 1/40.
# 2025-02-27 11:19:44,049 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:49,889 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:55,108 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:19:59,389 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:20:01,969 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:20:06,166 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:20:10,775 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:20:17,124 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:20:21,219 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:20:27,671 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:20:32,586 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:20:40,267 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:20:43,339 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:20:50,405 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:20:55,752 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:21:00,692 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:21:04,228 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:21:10,482 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:21:26,347 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:21:30,647 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:21:43,141 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:21:48,772 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:22:02,903 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:22:07,511 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:22:13,153 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:22:17,546 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:22:28,708 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:22:34,340 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:22:39,972 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:22:45,220 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:22:58,506 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:23:04,651 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:23:14,964 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:23:20,625 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:23:25,540 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:23:31,377 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:23:38,797 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:23:44,106 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:23:57,694 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:24:11,313 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:24:14,999 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:24:22,684 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:24:30,711 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:24:39,985 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:24:52,397 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:24:57,085 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:25:00,156 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:25:05,687 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:25:11,524 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:25:14,289 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:25:14,314 - INFO - Successfully generated and stores resumes for batch 2/40.
# 2025-02-27 11:25:20,738 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:25:25,658 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:25:35,485 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:25:39,506 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:25:43,473 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:25:52,819 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:25:57,480 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:02,518 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:05,794 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:11,478 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:15,300 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:20,644 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:24,330 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:30,167 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:34,773 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:38,257 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:42,325 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:45,551 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:50,443 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:54,129 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:26:57,937 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:27:04,779 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:27:08,568 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:27:23,928 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:27:29,569 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:27:47,171 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:27:53,419 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:27:59,254 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:28:01,886 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:28:06,012 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:28:12,158 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:28:23,829 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:28:28,440 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:28:35,198 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:28:40,113 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:28:49,332 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:29:06,430 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:29:12,062 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:29:16,671 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:29:22,201 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:29:30,084 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:29:36,643 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:29:40,945 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:29:43,396 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:29:46,469 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:29:52,305 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:29:54,763 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:30:02,545 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:30:09,839 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:30:17,143 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:30:17,198 - INFO - Successfully generated and stores resumes for batch 3/40.
# 2025-02-27 11:30:23,947 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:30:31,013 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:30:43,301 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:30:50,673 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:30:58,350 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:31:06,033 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:31:13,713 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:31:21,394 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:31:28,763 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:31:32,452 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:31:37,698 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:31:41,368 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:31:44,433 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:31:49,039 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:31:51,806 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:32:01,942 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:32:07,787 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:32:17,304 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:32:23,755 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:32:32,050 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:32:40,652 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:32:44,144 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:32:53,861 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:32:56,829 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:33:00,619 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:33:05,225 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:33:08,913 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:33:12,906 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:33:17,828 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:33:23,657 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:33:31,954 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:33:37,996 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:33:44,547 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:33:44,552 - ERROR - Error in Fireworks API call for user 1102238: list index out of range
# 2025-02-27 11:33:50,386 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:33:57,425 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:34:02,114 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:34:08,203 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:34:12,812 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:34:17,169 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:34:20,492 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:34:26,329 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:34:31,243 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:34:31,247 - ERROR - Error in Fireworks API call for user 802986: list index out of range
# 2025-02-27 11:34:37,081 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:34:42,917 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:34:52,133 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:02,108 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:09,028 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:14,867 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:21,678 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:27,357 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:27,373 - INFO - Successfully generated and stores resumes for batch 4/40.
# 2025-02-27 11:35:32,991 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:38,521 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:45,688 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:50,198 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:52,867 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:57,362 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:35:59,717 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:36:04,221 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:36:09,547 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:36:22,552 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:36:25,624 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:36:35,506 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:36:43,237 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:36:48,562 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:36:53,785 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:02,079 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:08,223 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:13,752 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:18,975 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:21,741 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:24,608 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:26,654 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:29,420 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:31,570 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:34,027 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:42,937 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:37:46,931 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:38:03,007 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:38:12,427 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 502 Bad Gateway"
# 2025-02-27 11:38:12,430 - ERROR - Error in Fireworks API call for user 1151533: {'error': {'object': 'error', 'type': 'internal_server_error', 'message': 'Bad Gateway'}}
# 2025-02-27 11:38:12,431 - ERROR - Error in Fireworks API call for user 1151533: 'NoneType' object has no attribute 'split'
# 2025-02-27 11:38:23,794 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:38:29,746 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:38:36,616 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:38:40,965 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:38:44,900 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:38:49,905 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:39:00,318 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:39:04,651 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:39:09,568 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:39:13,868 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:39:17,143 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:39:23,698 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:39:28,614 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:39:33,025 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:39:40,287 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:39:46,431 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:39:56,875 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:01,484 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:06,092 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:16,230 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:22,681 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:22,714 - INFO - Successfully generated and stores resumes for batch 5/40.
# 2025-02-27 11:40:29,746 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:34,662 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:38,348 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:41,215 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:45,209 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:49,407 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:54,015 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:40:58,316 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:41:03,845 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:41:09,682 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:41:21,053 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:41:30,262 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:41:36,409 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:41:41,756 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:41:53,613 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:41:59,142 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:42:10,926 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:42:14,297 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:42:21,260 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:42:27,098 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:42:38,465 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:42:41,967 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:42:48,294 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:43:00,890 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:43:08,264 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:43:25,107 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:43:32,532 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:43:36,422 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:43:38,884 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:43:54,138 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:44:12,365 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:44:12,369 - ERROR - Error in Fireworks API call for user 676133: list index out of range
# 2025-02-27 11:44:17,792 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:44:24,039 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:44:29,672 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:44:35,815 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:44:41,653 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:44:45,331 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:44:52,100 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:45:08,988 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:45:12,064 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:45:21,281 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:45:25,580 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:45:31,725 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:45:36,333 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:45:42,477 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:45:49,542 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:45:53,843 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:45:57,119 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:46:00,908 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:46:06,746 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:46:06,779 - INFO - Successfully generated and stores resumes for batch 6/40.
# 2025-02-27 11:46:12,275 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:46:18,418 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:46:23,334 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:46:29,172 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:46:36,032 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:46:41,459 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:46:47,603 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:46:54,974 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:46:58,193 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:47:02,654 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:47:10,029 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:47:14,635 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:47:20,166 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:47:24,885 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:47:29,382 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:47:36,448 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:47:44,437 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:47:52,730 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:47:56,530 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:48:03,583 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:48:09,016 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:48:18,844 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:48:24,064 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:48:24,070 - ERROR - Error in Fireworks API call for user 42543: list index out of range
# 2025-02-27 11:48:29,291 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:48:33,547 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:48:55,403 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:48:58,863 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:49:01,849 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:49:05,844 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:49:08,915 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:49:14,140 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:49:34,412 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:49:38,406 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:49:44,247 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:49:47,622 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:49:51,002 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:03,801 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:06,943 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:11,277 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:14,656 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:20,800 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:20,806 - ERROR - Error in Fireworks API call for user 631672: list index out of range
# 2025-02-27 11:50:26,649 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:31,859 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:36,164 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:38,925 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:41,792 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:47,527 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:54,596 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:50:58,893 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:05,344 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:05,377 - INFO - Successfully generated and stores resumes for batch 7/40.
# 2025-02-27 11:51:09,827 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:12,410 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:14,873 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:17,632 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:22,552 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:26,274 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:32,071 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:36,985 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:40,979 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:43,947 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:47,431 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:52,652 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:56,465 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:58,799 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:51:58,804 - ERROR - Error in Fireworks API call for user 1386499: list index out of range
# 2025-02-27 11:52:02,436 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:52:06,895 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:52:13,544 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:52:17,229 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:52:20,915 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:52:25,831 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:52:39,458 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:52:44,877 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:52:49,485 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:52:57,445 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:05,050 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:14,368 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:18,361 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:21,127 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:24,197 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:27,271 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:30,034 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:34,644 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:44,171 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:49,389 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:53,997 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:53:59,220 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 11:54:05,671 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# ...
# 2025-02-27 14:01:21,543 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:01:27,194 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:01:30,458 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:01:38,029 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:01:42,641 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:01:47,051 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:01:51,234 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:01:55,846 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:02:00,863 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:02:04,753 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:02:11,824 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:02:15,815 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:02:21,038 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:02:24,006 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:02:29,023 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:02:47,047 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:02:50,246 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:02:53,295 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:02:56,978 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:03:01,395 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:03:09,881 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:03:15,102 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:03:18,795 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:03:19,915 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 502 Bad Gateway"
# 2025-02-27 14:03:19,917 - ERROR - Error in Fireworks API call for user 1312307: {'error': {'object': 'error', 'type': 'internal_server_error', 'message': 'Bad Gateway'}}
# 2025-02-27 14:03:19,918 - ERROR - Error in Fireworks API call for user 1312307: 'NoneType' object has no attribute 'split'
# 2025-02-27 14:03:19,939 - INFO - Successfully generated and stores resumes for batch 38/40.
# 2025-02-27 14:03:25,242 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:03:41,320 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:03:44,596 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:03:47,669 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:03:53,707 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:03:59,955 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:03:59,960 - ERROR - Error in Fireworks API call for user 886951: list index out of range
# 2025-02-27 14:04:03,642 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:07,023 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:12,243 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:15,622 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:19,924 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:24,225 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:28,218 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:35,898 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:42,245 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:45,111 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:48,801 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:52,487 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:55,352 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:04:58,637 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:05:02,010 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:05:07,847 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:05:17,063 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:05:21,365 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:05:21,369 - ERROR - Error in Fireworks API call for user 614710: list index out of range
# 2025-02-27 14:05:28,427 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:05:33,959 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:05:39,490 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:05:44,207 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:00,685 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:02,837 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:05,703 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:07,548 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:10,211 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:13,280 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:17,887 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 502 Bad Gateway"
# 2025-02-27 14:06:17,890 - ERROR - Error in Fireworks API call for user 1230048: {'error': {'object': 'error', 'type': 'internal_server_error', 'message': 'Bad Gateway'}}
# 2025-02-27 14:06:17,892 - ERROR - Error in Fireworks API call for user 1230048: 'NoneType' object has no attribute 'split'
# 2025-02-27 14:06:22,527 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:27,104 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:31,610 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:34,787 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:41,339 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:46,149 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:06:54,138 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:07:00,284 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:07:07,859 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:07:13,189 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:07:17,917 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:07:22,073 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:07:25,576 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:07:28,313 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:07:31,924 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:07:31,948 - INFO - Successfully generated and stores resumes for batch 39/40.
# 2025-02-27 14:07:48,512 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:07:52,813 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:07:54,656 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:01,294 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:07,252 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:17,697 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:24,148 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:29,269 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:32,135 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:37,870 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:42,275 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:47,190 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:50,570 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:52,717 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:55,403 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:57,633 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:08:59,893 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:09:05,624 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:09:08,896 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:09:13,297 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:09:20,571 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:09:24,057 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:09:28,967 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:09:33,268 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:09:37,577 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:09:42,688 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:09:48,635 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:05,217 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:07,980 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:12,490 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:15,764 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:18,732 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:24,257 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:32,558 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:36,552 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:39,636 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:43,924 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:47,918 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:54,376 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:10:57,441 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:11:00,819 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:11:05,550 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:11:11,265 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:11:20,075 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:11:23,859 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:11:28,161 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:11:30,926 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:11:33,076 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:11:37,034 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:11:41,370 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"
# 2025-02-27 14:11:41,399 - INFO - Successfully generated and stores resumes for batch 40/40.

# %%
test_query_dict = orchestrate_LLM_query_build_batch([72])
test_query = build_LLM_query(test_query_dict)
# test_query
test_response = fireworks_api_call(query=test_query[72], user_id=72)

try:
    update_db = test_response.split('[BEGIN]')[1].split('[END]')[0].strip()
    cursor.execute('UPDATE users SET generated_resume=? WHERE user_id=72', (update_db,))
    con.commit()
    cursor.execute('SELECT * FROM users WHERE user_id=72').fetchall()
except Exception as e:
    print(test_response)
    logging.error(f'Error in orchestrating LLM query for user: {e}')
# Out:
# 2025-02-24 14:52:43,612 - INFO - HTTP Request: POST https://api.fireworks.ai/inference/v1/completions "HTTP/1.1 200 OK"

# %% [markdown]
# In the following section, I am trying to see what the median number of applications is per user WHO HAS a generated resume. This will inform the cutoff score for classifying users as highly active appliers (1) or not highly active appliers (0).

# %%
median_apps_query = '''
SELECT
    user_id,
    COUNT(*) AS n_apps
FROM
    apps
WHERE
    user_id IN (
        SELECT
            user_id
        FROM
            users
        WHERE
            generated_resume NOT NULL
        )
GROUP BY user_id;'''


apps_stats = pd.read_sql_query(median_apps_query, con=con)

# %%
apps_stats.describe()
# Out:
#             user_id       n_apps
# count  5.004000e+03  5004.000000
# mean   7.405433e+05     4.440248
# std    4.220730e+05     7.250702
# min    4.700000e+01     1.000000
# 25%    3.701500e+05     1.000000
# 50%    7.460575e+05     2.000000
# 75%    1.106938e+06     5.000000
# max    1.472090e+06   100.000000

# %% [markdown]
# The median number of applications for this sample is 2. I think I will make the cutoff a bit higher at 5, which is the 75% quartile.

# %%
positive_class_users = apps_stats.loc[apps_stats['n_apps'] >= 5]['user_id'].to_list()
negative_class_users = apps_stats.loc[apps_stats['n_apps'] < 5]['user_id'].to_list()

positive_class_df = pd.read_sql_query(f'SELECT user_id, generated_resume FROM users WHERE user_id IN ({", ".join(map(str, positive_class_users))})', con=con)
negative_class_df = pd.read_sql_query(f'SELECT user_id, generated_resume FROM users WHERE user_id IN ({", ".join(map(str, negative_class_users))})', con=con)

# %% [markdown]
# At this point, I'm going to export the user dataframes to parquet so that I can upload them to Google Colab and make use of the GPU instances there.

# %%
positive_class_df.to_parquet('./positive_class.parquet')
negative_class_df.to_parquet('./negative_class.parquet')
